# %%
from transformers import BertTokenizer, AutoModelForSequenceClassification
from transformers_interpret import SequenceClassificationExplainer
from readers import lenta_reader, ria_reader
from tqdm.notebook import tqdm
from collections import Counter
import numpy as np
import matplotlib.pyplot as plt
import random

# %%
tokenizer_path = '/home/aobuhtijarov/models/rubert_cased_L-12_H-768_A-12_pt/'
model_path = '/home/aobuhtijarov/models/discriminator_on_clusters_from_rubert/''
lenta_path = '/home/aobuhtijarov/datasets/lenta/lenta-ru-news.test.csv'
ria_path = '/home/aobuhtijarov/datasets/ria/ria.shuffled.test.json'

# %%
tokenizer = BertTokenizer.from_pretrained(tokenizer_path, do_lower_case=False, do_basic_tokenize=False)
model = AutoModelForSequenceClassification.from_pretrained(model_path, num_labels=2, output_attentions=True)

# %%
import json

def reader(path):
    with open(path, 'r') as f:
        for line in f:
            yield json.loads(line.strip())
            
            
records = [r for r in tqdm(reader('../../datasets/full_lenta_ria.test.jsonl'))]
# Out:
# 0it [00:00, ?it/s]

# %%
lenta_records = [
    {'text': r['lenta_text'], 'title': r['lenta_title'], 'agency': 'lenta.ru', 'date': r['lenta_date']} 
    for r in records
]

ria_records = [
    {'text': r['ria_text'], 'title': r['ria_title'], 'agency': 'РИА Новости', 'date': r['lenta_date']} 
    for r in records
]

# %%
agency_list = ["РИА Новости", "lenta.ru"]
agency_to_special_token_id = {a: tokenizer.vocab[f'[unused{i+1}]'] for i, a in enumerate(agency_list)}
agency_to_discr_target = {a: i for i, a in enumerate(sorted(agency_list))}
discr_target_to_agency = {v: k for k, v in agency_to_discr_target.items()}

cname_to_agency = { 
    f'LABEL_{i}': discr_target_to_agency[i] for i in range(len(agency_list))
}

# %%
# lenta_records = [r for r in tqdm(lenta_reader(lenta_path))][:20000]
# ria_records = [r for r in tqdm(ria_reader(ria_path))][:20000]

# %%
# n = random.randint(0, 43000)
# lenta_records[n]['title'], ria_records[n]['title']

# %% [markdown]
# ## Predictions

# %%
# model.cuda();

# %%
cls_explainer = SequenceClassificationExplainer(model, tokenizer)

# %% [markdown]
# ### Lenta

# %%
lenta_results = []
lenta_pred_cnt = 0

for r in tqdm(lenta_records, total=len(lenta_records)):
    if len(r['title']) > 150:
        print(r)
        continue
    
    val = cls_explainer(r['title'].lower())
    
    if cname_to_agency[cls_explainer.predicted_class_name] == 'lenta.ru':
        lenta_pred_cnt += 1
        lenta_results.extend(val)
# Out:
#   0%|          | 0/2000 [00:00<?, ?it/s]
# {'text': 'экономика', 'title': '"газпром" и турецкая botas подписали дополнения к долгосрочным контрактам на поставки газа, согласно которым объем экспорта топлива в турцию увеличится как минимум на 2 миллиарда кубометров. в 2011 году поставки газа в страну составят 25,8 миллиарда кубометров, что, по словам главы монополии алексея миллера, является абсолютным рекордом в рамках российско-турецкого сотрудничества. об этом сообщает "интерфакс". россия поставляет турции газ по трем контрактам: один по "голубому потоку" и два по западному маршруту транзитом через украину. действие одного из них, подписанного в 1986 году сроком на 25 лет, заканчивается в этом году. на переговорах 28 декабря botas и "газпром" подписали дополнения к двум другим контрактам: 25-летнего соглашения от 1997 года на поставки по "голубому потоку" и 23-летнего договора от 1998 года на поставки через украину. ранее botas отказалась продлевать соглашение 1986 года, пытаясь добиться от "газпрома" 20-процентной скидки. согласно подписанным дополнениям, объемы, оговоренные в этом контракте (6 миллиардов кубометров в год), перенесут на контракт от 1998 года по западному маршруту. как отметил миллер, в коммерческие условия поставок будут внесены "определенные дополнения", какие именно, не уточняется. глава монополии напомнил, что в этом году минимальные обязательства анкары по закупкам газа были определены на уровне в 24 миллиарда кубометров. турция является крупнейшим после германии партнером по закупкам газа у российской монополии. ранее 28 декабря стало известно, что турция выдала разрешение на строительство трубопровода "южный поток" по дну черного моря. проект был приостановлен в конце прошлого года, когда анкара потребовала проведения сейсмических исследований.', 'agency': 'lenta.ru', 'date': '2011-12-28 10:00'}

# %%
print('Lenta accuracy:', round(lenta_pred_cnt / len(lenta_records), 2))
# Out:
# Lenta accuracy: 0.89

# %% [markdown]
# ### RIA

# %%
ria_results = []
ria_pred_cnt = 0

for r in tqdm(ria_records, total=len(ria_records)):
    if len(r['title']) > 150:
        print(r)
        continue

    val = cls_explainer(r['title'].lower())
    if cname_to_agency[cls_explainer.predicted_class_name] == 'РИА Новости':
        ria_pred_cnt += 1
        ria_results.extend(val)
# Out:
#   0%|          | 0/2000 [00:00<?, ?it/s]

# %%
print('RIA accuracy:', round(ria_pred_cnt / len(ria_records), 2))
# Out:
# RIA accuracy: 0.85

# %% [markdown]
# ### General discriminator analysis

# %%
def extract_top_n_words(res, percentile=85, n=20):
    p = np.percentile([x[1] for x in res], percentile)
    top_tokens = [x[0] for x in res if x[1] >= p]
    return Counter(top_tokens).most_common(n)

# %%
lenta_results = [(a, b) for a, b in lenta_results if a not in ['[CLS]', '[SEP]']]
ria_results = [(a, b) for a, b in ria_results if a not in ['[CLS]', '[SEP]']]

# %% [markdown]
# `
# Positive attribution numbers indicate a word contributes positively towards the predicted class, while negative numbers indicate a word contributes negatively towards the predicted class
# `

# %% [markdown]
# #### Lenta

# %% [markdown]
# Positive

# %%
extract_top_n_words(lenta_results)
# Out:
# [('в', 137),
#  ('##-', 43),
#  ('##а', 37),
#  ('за', 36),
#  ('о', 34),
#  ('##и', 34),
#  ('на', 33),
#  ('##е', 30),
#  ('с', 17),
#  ('об', 13),
#  ('##о', 12),
#  ('##у', 12),
#  ('и', 12),
#  ('умер', 11),
#  ('##ев', 11),
#  ('по', 10),
#  ('потребовали', 10),
#  ('предъявили', 9),
#  ('заподозрили', 9),
#  ('##н', 9)]

# %% [markdown]
# Negative

# %%
extract_top_n_words([(x[0], -x[1]) for x in lenta_results])
# Out:
# [('"', 192),
#  ('##"', 126),
#  ('в', 109),
#  ('на', 94),
#  ('##ии', 47),
#  ('##а', 26),
#  ('за', 22),
#  ('от', 20),
#  ('из', 18),
#  ('##ы', 18),
#  ('по', 18),
#  ('о', 17),
#  ('росс', 16),
#  ('и', 15),
#  ('##-', 14),
#  ('##е', 14),
#  ('##и', 13),
#  ('с', 12),
#  ('##н', 12),
#  ('москв', 12)]

# %% [markdown]
# #### RIA

# %% [markdown]
# Positive

# %%
extract_top_n_words(ria_results)
# Out:
# [(',', 279),
#  ('в', 220),
#  ('##:', 87),
#  ('-', 74),
#  ('"', 39),
#  ('$', 37),
#  ('млрд', 37),
#  ('млн', 27),
#  ('##%', 26),
#  ('на', 26),
#  ('может', 25),
#  ('##е', 25),
#  ('##ф', 23),
#  ('руб', 23),
#  ('г', 23),
#  ('о', 21),
#  ('по', 21),
#  ('из', 18),
#  ('##ии', 17),
#  ('экс', 16)]

# %% [markdown]
# Negative

# %%
extract_top_n_words([(x[0], -x[1]) for x in ria_results])
# Out:
# [('в', 112),
#  ('##-', 42),
#  ('на', 39),
#  ('о', 23),
#  ('с', 22),
#  (',', 22),
#  ('москв', 21),
#  ('р', 20),
#  ('и', 20),
#  ('по', 18),
#  ('человек', 18),
#  ('сш', 16),
#  ('##ии', 16),
#  ('##ф', 14),
#  ('"', 14),
#  ('из', 13),
#  ('##"', 13),
#  ('##н', 13),
#  ('под', 12),
#  ('против', 12)]

# %% [markdown]
# ### Visualization on concrete examples

# %%
for target, sent in (
        ('Lenta', 'в столичной квартире нашли тела пенсионерки и ее сына-инвалида'),
        ('Lenta', 'американцы начали подавать иски против китая из-за коронавируса'),
        ('Lenta', 'стал известен источник полученных тимошенко миллионов долларов'),
        ('Lenta', 'названо преимущество полноценного сна перед конфетами'),
        ('TASS', 'коллекторы считают, что 40% сотрудников компаний могут просрочить платежи по кредитам'),
        ('TASS', 'более 40 военнослужащих рф, задействованных в борьбе с пандемией, вернулись из италии'),
        ('RT', 'климкин заявил об отсутствии у россии «права» праздновать день победы'),
        ('RT', 'в минобороны прокомментировали возвращение специалистов из италии'),
    
    ):
    cls_explainer(sent.lower());
    print(' ' * 72 + f'True: {target}; Pred: {cname_to_agency[cls_explainer.predicted_class_name]}')
    cls_explainer.visualize('bert-discr-vis.html')
# Out:
#                                                                         True: Lenta; Pred: Lenta
# <table width: 100%><div style="border-top: 1px solid; margin-top: 5px;             padding-top: 5px; display: inline-block"><b>Legend: </b><span style="display: inline-block; width: 10px; height: 10px;                 border: 1px solid; background-color:                 hsl(0, 75%, 60%)"></span> Negative  <span style="display: inline-block; width: 10px; height: 10px;                 border: 1px solid; background-color:                 hsl(0, 75%, 100%)"></span> Neutral  <span style="display: inline-block; width: 10px; height: 10px;                 border: 1px solid; background-color:                 hsl(120, 75%, 50%)"></span> Positive  </div><tr><th>True Label</th><th>Predicted Label</th><th>Attribution Label</th><th>Attribution Score</th><th>Word Importance</th><tr><td><text style="padding-right:2em"><b>1</b></text></td><td><text style="padding-right:2em"><b>LABEL_1 (0.89)</b></text></td><td><text style="padding-right:2em"><b>LABEL_1</b></text></td><td><text style="padding-right:2em"><b>1.22</b></text></td><td><mark style="background-color: hsl(0, 75%, 100%); opacity:1.0;                     line-height:1.75"><font color="black"> [CLS]                    </font></mark><mark style="background-color: hsl(120, 75%, 100%); opacity:1.0;                     line-height:1.75"><font color="black"> в                    </font></mark><mark style="background-color: hsl(120, 75%, 64%); opacity:1.0;                     line-height:1.75"><font color="black"> столичной                    </font></mark><mark style="background-color: hsl(120, 75%, 83%); opacity:1.0;                     line-height:1.75"><font color="black"> квартире                    </font></mark><mark style="background-color: hsl(0, 75%, 86%); opacity:1.0;                     line-height:1.75"><font color="black"> нашли                    </font></mark><mark style="background-color: hsl(120, 75%, 93%); opacity:1.0;                     line-height:1.75"><font color="black"> тела                    </font></mark><mark style="background-color: hsl(120, 75%, 80%); opacity:1.0;                     line-height:1.75"><font color="black"> пенсионер                    </font></mark><mark style="background-color: hsl(120, 75%, 100%); opacity:1.0;                     line-height:1.75"><font color="black"> ##ки                    </font></mark><mark style="background-color: hsl(0, 75%, 100%); opacity:1.0;                     line-height:1.75"><font color="black"> и                    </font></mark><mark style="background-color: hsl(0, 75%, 96%); opacity:1.0;                     line-height:1.75"><font color="black"> ее                    </font></mark><mark style="background-color: hsl(120, 75%, 99%); opacity:1.0;                     line-height:1.75"><font color="black"> сына                    </font></mark><mark style="background-color: hsl(0, 75%, 99%); opacity:1.0;                     line-height:1.75"><font color="black"> ##-                    </font></mark><mark style="background-color: hsl(120, 75%, 99%); opacity:1.0;                     line-height:1.75"><font color="black"> ##ин                    </font></mark><mark style="background-color: hsl(120, 75%, 97%); opacity:1.0;                     line-height:1.75"><font color="black"> ##вали                    </font></mark><mark style="background-color: hsl(0, 75%, 99%); opacity:1.0;                     line-height:1.75"><font color="black"> ##да                    </font></mark><mark style="background-color: hsl(0, 75%, 100%); opacity:1.0;                     line-height:1.75"><font color="black"> [SEP]                    </font></mark></td><tr></table>
#                                                                         True: Lenta; Pred: Lenta
# <table width: 100%><div style="border-top: 1px solid; margin-top: 5px;             padding-top: 5px; display: inline-block"><b>Legend: </b><span style="display: inline-block; width: 10px; height: 10px;                 border: 1px solid; background-color:                 hsl(0, 75%, 60%)"></span> Negative  <span style="display: inline-block; width: 10px; height: 10px;                 border: 1px solid; background-color:                 hsl(0, 75%, 100%)"></span> Neutral  <span style="display: inline-block; width: 10px; height: 10px;                 border: 1px solid; background-color:                 hsl(120, 75%, 50%)"></span> Positive  </div><tr><th>True Label</th><th>Predicted Label</th><th>Attribution Label</th><th>Attribution Score</th><th>Word Importance</th><tr><td><text style="padding-right:2em"><b>1</b></text></td><td><text style="padding-right:2em"><b>LABEL_1 (1.00)</b></text></td><td><text style="padding-right:2em"><b>LABEL_1</b></text></td><td><text style="padding-right:2em"><b>2.91</b></text></td><td><mark style="background-color: hsl(0, 75%, 100%); opacity:1.0;                     line-height:1.75"><font color="black"> [CLS]                    </font></mark><mark style="background-color: hsl(120, 75%, 96%); opacity:1.0;                     line-height:1.75"><font color="black"> американцы                    </font></mark><mark style="background-color: hsl(120, 75%, 95%); opacity:1.0;                     line-height:1.75"><font color="black"> начали                    </font></mark><mark style="background-color: hsl(120, 75%, 93%); opacity:1.0;                     line-height:1.75"><font color="black"> подавать                    </font></mark><mark style="background-color: hsl(120, 75%, 94%); opacity:1.0;                     line-height:1.75"><font color="black"> иски                    </font></mark><mark style="background-color: hsl(120, 75%, 97%); opacity:1.0;                     line-height:1.75"><font color="black"> против                    </font></mark><mark style="background-color: hsl(120, 75%, 90%); opacity:1.0;                     line-height:1.75"><font color="black"> кита                    </font></mark><mark style="background-color: hsl(120, 75%, 69%); opacity:1.0;                     line-height:1.75"><font color="black"> ##я                    </font></mark><mark style="background-color: hsl(120, 75%, 86%); opacity:1.0;                     line-height:1.75"><font color="black"> из                    </font></mark><mark style="background-color: hsl(120, 75%, 97%); opacity:1.0;                     line-height:1.75"><font color="black"> ##-                    </font></mark><mark style="background-color: hsl(120, 75%, 87%); opacity:1.0;                     line-height:1.75"><font color="black"> ##за                    </font></mark><mark style="background-color: hsl(120, 75%, 88%); opacity:1.0;                     line-height:1.75"><font color="black"> корона                    </font></mark><mark style="background-color: hsl(120, 75%, 75%); opacity:1.0;                     line-height:1.75"><font color="black"> ##вир                    </font></mark><mark style="background-color: hsl(120, 75%, 93%); opacity:1.0;                     line-height:1.75"><font color="black"> ##уса                    </font></mark><mark style="background-color: hsl(0, 75%, 100%); opacity:1.0;                     line-height:1.75"><font color="black"> [SEP]                    </font></mark></td><tr></table>
#                                                                         True: Lenta; Pred: Lenta
# <table width: 100%><div style="border-top: 1px solid; margin-top: 5px;             padding-top: 5px; display: inline-block"><b>Legend: </b><span style="display: inline-block; width: 10px; height: 10px;                 border: 1px solid; background-color:                 hsl(0, 75%, 60%)"></span> Negative  <span style="display: inline-block; width: 10px; height: 10px;                 border: 1px solid; background-color:                 hsl(0, 75%, 100%)"></span> Neutral  <span style="display: inline-block; width: 10px; height: 10px;                 border: 1px solid; background-color:                 hsl(120, 75%, 50%)"></span> Positive  </div><tr><th>True Label</th><th>Predicted Label</th><th>Attribution Label</th><th>Attribution Score</th><th>Word Importance</th><tr><td><text style="padding-right:2em"><b>1</b></text></td><td><text style="padding-right:2em"><b>LABEL_1 (1.00)</b></text></td><td><text style="padding-right:2em"><b>LABEL_1</b></text></td><td><text style="padding-right:2em"><b>2.67</b></text></td><td><mark style="background-color: hsl(0, 75%, 100%); opacity:1.0;                     line-height:1.75"><font color="black"> [CLS]                    </font></mark><mark style="background-color: hsl(120, 75%, 87%); opacity:1.0;                     line-height:1.75"><font color="black"> стал                    </font></mark><mark style="background-color: hsl(120, 75%, 85%); opacity:1.0;                     line-height:1.75"><font color="black"> известен                    </font></mark><mark style="background-color: hsl(120, 75%, 87%); opacity:1.0;                     line-height:1.75"><font color="black"> источник                    </font></mark><mark style="background-color: hsl(0, 75%, 94%); opacity:1.0;                     line-height:1.75"><font color="black"> полученных                    </font></mark><mark style="background-color: hsl(120, 75%, 88%); opacity:1.0;                     line-height:1.75"><font color="black"> тим                    </font></mark><mark style="background-color: hsl(120, 75%, 80%); opacity:1.0;                     line-height:1.75"><font color="black"> ##оше                    </font></mark><mark style="background-color: hsl(120, 75%, 82%); opacity:1.0;                     line-height:1.75"><font color="black"> ##н                    </font></mark><mark style="background-color: hsl(120, 75%, 96%); opacity:1.0;                     line-height:1.75"><font color="black"> ##ко                    </font></mark><mark style="background-color: hsl(120, 75%, 77%); opacity:1.0;                     line-height:1.75"><font color="black"> миллионов                    </font></mark><mark style="background-color: hsl(120, 75%, 81%); opacity:1.0;                     line-height:1.75"><font color="black"> долларов                    </font></mark><mark style="background-color: hsl(0, 75%, 100%); opacity:1.0;                     line-height:1.75"><font color="black"> [SEP]                    </font></mark></td><tr></table>
#                                                                         True: Lenta; Pred: Lenta
# <table width: 100%><div style="border-top: 1px solid; margin-top: 5px;             padding-top: 5px; display: inline-block"><b>Legend: </b><span style="display: inline-block; width: 10px; height: 10px;                 border: 1px solid; background-color:                 hsl(0, 75%, 60%)"></span> Negative  <span style="display: inline-block; width: 10px; height: 10px;                 border: 1px solid; background-color:                 hsl(0, 75%, 100%)"></span> Neutral  <span style="display: inline-block; width: 10px; height: 10px;                 border: 1px solid; background-color:                 hsl(120, 75%, 50%)"></span> Positive  </div><tr><th>True Label</th><th>Predicted Label</th><th>Attribution Label</th><th>Attribution Score</th><th>Word Importance</th><tr><td><text style="padding-right:2em"><b>1</b></text></td><td><text style="padding-right:2em"><b>LABEL_1 (1.00)</b></text></td><td><text style="padding-right:2em"><b>LABEL_1</b></text></td><td><text style="padding-right:2em"><b>2.22</b></text></td><td><mark style="background-color: hsl(0, 75%, 100%); opacity:1.0;                     line-height:1.75"><font color="black"> [CLS]                    </font></mark><mark style="background-color: hsl(120, 75%, 81%); opacity:1.0;                     line-height:1.75"><font color="black"> названо                    </font></mark><mark style="background-color: hsl(120, 75%, 81%); opacity:1.0;                     line-height:1.75"><font color="black"> преимущество                    </font></mark><mark style="background-color: hsl(120, 75%, 72%); opacity:1.0;                     line-height:1.75"><font color="black"> полноценного                    </font></mark><mark style="background-color: hsl(120, 75%, 73%); opacity:1.0;                     line-height:1.75"><font color="black"> сна                    </font></mark><mark style="background-color: hsl(120, 75%, 87%); opacity:1.0;                     line-height:1.75"><font color="black"> перед                    </font></mark><mark style="background-color: hsl(0, 75%, 99%); opacity:1.0;                     line-height:1.75"><font color="black"> конфет                    </font></mark><mark style="background-color: hsl(120, 75%, 96%); opacity:1.0;                     line-height:1.75"><font color="black"> ##ами                    </font></mark><mark style="background-color: hsl(0, 75%, 100%); opacity:1.0;                     line-height:1.75"><font color="black"> [SEP]                    </font></mark></td><tr></table>
#                                                                         True: TASS; Pred: TASS
# <table width: 100%><div style="border-top: 1px solid; margin-top: 5px;             padding-top: 5px; display: inline-block"><b>Legend: </b><span style="display: inline-block; width: 10px; height: 10px;                 border: 1px solid; background-color:                 hsl(0, 75%, 60%)"></span> Negative  <span style="display: inline-block; width: 10px; height: 10px;                 border: 1px solid; background-color:                 hsl(0, 75%, 100%)"></span> Neutral  <span style="display: inline-block; width: 10px; height: 10px;                 border: 1px solid; background-color:                 hsl(120, 75%, 50%)"></span> Positive  </div><tr><th>True Label</th><th>Predicted Label</th><th>Attribution Label</th><th>Attribution Score</th><th>Word Importance</th><tr><td><text style="padding-right:2em"><b>2</b></text></td><td><text style="padding-right:2em"><b>LABEL_2 (1.00)</b></text></td><td><text style="padding-right:2em"><b>LABEL_2</b></text></td><td><text style="padding-right:2em"><b>2.35</b></text></td><td><mark style="background-color: hsl(0, 75%, 100%); opacity:1.0;                     line-height:1.75"><font color="black"> [CLS]                    </font></mark><mark style="background-color: hsl(120, 75%, 88%); opacity:1.0;                     line-height:1.75"><font color="black"> коллектор                    </font></mark><mark style="background-color: hsl(0, 75%, 97%); opacity:1.0;                     line-height:1.75"><font color="black"> ##ы                    </font></mark><mark style="background-color: hsl(120, 75%, 86%); opacity:1.0;                     line-height:1.75"><font color="black"> считают                    </font></mark><mark style="background-color: hsl(120, 75%, 99%); opacity:1.0;                     line-height:1.75"><font color="black"> ,                    </font></mark><mark style="background-color: hsl(120, 75%, 96%); opacity:1.0;                     line-height:1.75"><font color="black"> что                    </font></mark><mark style="background-color: hsl(120, 75%, 92%); opacity:1.0;                     line-height:1.75"><font color="black"> 40                    </font></mark><mark style="background-color: hsl(120, 75%, 94%); opacity:1.0;                     line-height:1.75"><font color="black"> ##%                    </font></mark><mark style="background-color: hsl(120, 75%, 93%); opacity:1.0;                     line-height:1.75"><font color="black"> сотрудников                    </font></mark><mark style="background-color: hsl(0, 75%, 100%); opacity:1.0;                     line-height:1.75"><font color="black"> компаний                    </font></mark><mark style="background-color: hsl(120, 75%, 64%); opacity:1.0;                     line-height:1.75"><font color="black"> могут                    </font></mark><mark style="background-color: hsl(0, 75%, 93%); opacity:1.0;                     line-height:1.75"><font color="black"> просроч                    </font></mark><mark style="background-color: hsl(120, 75%, 92%); opacity:1.0;                     line-height:1.75"><font color="black"> ##ить                    </font></mark><mark style="background-color: hsl(120, 75%, 89%); opacity:1.0;                     line-height:1.75"><font color="black"> платежи                    </font></mark><mark style="background-color: hsl(120, 75%, 83%); opacity:1.0;                     line-height:1.75"><font color="black"> по                    </font></mark><mark style="background-color: hsl(120, 75%, 97%); opacity:1.0;                     line-height:1.75"><font color="black"> кредитам                    </font></mark><mark style="background-color: hsl(0, 75%, 100%); opacity:1.0;                     line-height:1.75"><font color="black"> [SEP]                    </font></mark></td><tr></table>
#                                                                         True: TASS; Pred: TASS
# <table width: 100%><div style="border-top: 1px solid; margin-top: 5px;             padding-top: 5px; display: inline-block"><b>Legend: </b><span style="display: inline-block; width: 10px; height: 10px;                 border: 1px solid; background-color:                 hsl(0, 75%, 60%)"></span> Negative  <span style="display: inline-block; width: 10px; height: 10px;                 border: 1px solid; background-color:                 hsl(0, 75%, 100%)"></span> Neutral  <span style="display: inline-block; width: 10px; height: 10px;                 border: 1px solid; background-color:                 hsl(120, 75%, 50%)"></span> Positive  </div><tr><th>True Label</th><th>Predicted Label</th><th>Attribution Label</th><th>Attribution Score</th><th>Word Importance</th><tr><td><text style="padding-right:2em"><b>2</b></text></td><td><text style="padding-right:2em"><b>LABEL_2 (1.00)</b></text></td><td><text style="padding-right:2em"><b>LABEL_2</b></text></td><td><text style="padding-right:2em"><b>1.63</b></text></td><td><mark style="background-color: hsl(0, 75%, 100%); opacity:1.0;                     line-height:1.75"><font color="black"> [CLS]                    </font></mark><mark style="background-color: hsl(120, 75%, 97%); opacity:1.0;                     line-height:1.75"><font color="black"> более                    </font></mark><mark style="background-color: hsl(120, 75%, 100%); opacity:1.0;                     line-height:1.75"><font color="black"> 40                    </font></mark><mark style="background-color: hsl(0, 75%, 98%); opacity:1.0;                     line-height:1.75"><font color="black"> военнослужащих                    </font></mark><mark style="background-color: hsl(120, 75%, 100%); opacity:1.0;                     line-height:1.75"><font color="black"> р                    </font></mark><mark style="background-color: hsl(0, 75%, 100%); opacity:1.0;                     line-height:1.75"><font color="black"> ##ф                    </font></mark><mark style="background-color: hsl(0, 75%, 97%); opacity:1.0;                     line-height:1.75"><font color="black"> ,                    </font></mark><mark style="background-color: hsl(0, 75%, 86%); opacity:1.0;                     line-height:1.75"><font color="black"> задействованных                    </font></mark><mark style="background-color: hsl(0, 75%, 100%); opacity:1.0;                     line-height:1.75"><font color="black"> в                    </font></mark><mark style="background-color: hsl(120, 75%, 99%); opacity:1.0;                     line-height:1.75"><font color="black"> борьбе                    </font></mark><mark style="background-color: hsl(120, 75%, 91%); opacity:1.0;                     line-height:1.75"><font color="black"> с                    </font></mark><mark style="background-color: hsl(120, 75%, 93%); opacity:1.0;                     line-height:1.75"><font color="black"> панд                    </font></mark><mark style="background-color: hsl(120, 75%, 95%); opacity:1.0;                     line-height:1.75"><font color="black"> ##емией                    </font></mark><mark style="background-color: hsl(0, 75%, 100%); opacity:1.0;                     line-height:1.75"><font color="black"> ,                    </font></mark><mark style="background-color: hsl(120, 75%, 90%); opacity:1.0;                     line-height:1.75"><font color="black"> вернулись                    </font></mark><mark style="background-color: hsl(120, 75%, 66%); opacity:1.0;                     line-height:1.75"><font color="black"> из                    </font></mark><mark style="background-color: hsl(120, 75%, 85%); opacity:1.0;                     line-height:1.75"><font color="black"> итал                    </font></mark><mark style="background-color: hsl(120, 75%, 82%); opacity:1.0;                     line-height:1.75"><font color="black"> ##ии                    </font></mark><mark style="background-color: hsl(0, 75%, 100%); opacity:1.0;        ...
#                                                                         True: RT; Pred: RT
# <table width: 100%><div style="border-top: 1px solid; margin-top: 5px;             padding-top: 5px; display: inline-block"><b>Legend: </b><span style="display: inline-block; width: 10px; height: 10px;                 border: 1px solid; background-color:                 hsl(0, 75%, 60%)"></span> Negative  <span style="display: inline-block; width: 10px; height: 10px;                 border: 1px solid; background-color:                 hsl(0, 75%, 100%)"></span> Neutral  <span style="display: inline-block; width: 10px; height: 10px;                 border: 1px solid; background-color:                 hsl(120, 75%, 50%)"></span> Positive  </div><tr><th>True Label</th><th>Predicted Label</th><th>Attribution Label</th><th>Attribution Score</th><th>Word Importance</th><tr><td><text style="padding-right:2em"><b>0</b></text></td><td><text style="padding-right:2em"><b>LABEL_0 (0.97)</b></text></td><td><text style="padding-right:2em"><b>LABEL_0</b></text></td><td><text style="padding-right:2em"><b>1.23</b></text></td><td><mark style="background-color: hsl(0, 75%, 100%); opacity:1.0;                     line-height:1.75"><font color="black"> [CLS]                    </font></mark><mark style="background-color: hsl(120, 75%, 68%); opacity:1.0;                     line-height:1.75"><font color="black"> клим                    </font></mark><mark style="background-color: hsl(0, 75%, 78%); opacity:1.0;                     line-height:1.75"><font color="black"> ##кин                    </font></mark><mark style="background-color: hsl(120, 75%, 93%); opacity:1.0;                     line-height:1.75"><font color="black"> заявил                    </font></mark><mark style="background-color: hsl(120, 75%, 95%); opacity:1.0;                     line-height:1.75"><font color="black"> об                    </font></mark><mark style="background-color: hsl(120, 75%, 98%); opacity:1.0;                     line-height:1.75"><font color="black"> отсутствии                    </font></mark><mark style="background-color: hsl(120, 75%, 98%); opacity:1.0;                     line-height:1.75"><font color="black"> у                    </font></mark><mark style="background-color: hsl(120, 75%, 91%); opacity:1.0;                     line-height:1.75"><font color="black"> росс                    </font></mark><mark style="background-color: hsl(0, 75%, 98%); opacity:1.0;                     line-height:1.75"><font color="black"> ##ии                    </font></mark><mark style="background-color: hsl(0, 75%, 100%); opacity:1.0;                     line-height:1.75"><font color="black"> «                    </font></mark><mark style="background-color: hsl(120, 75%, 96%); opacity:1.0;                     line-height:1.75"><font color="black"> ##прав                    </font></mark><mark style="background-color: hsl(120, 75%, 99%); opacity:1.0;                     line-height:1.75"><font color="black"> ##а                    </font></mark><mark style="background-color: hsl(0, 75%, 99%); opacity:1.0;                     line-height:1.75"><font color="black"> ##»                    </font></mark><mark style="background-color: hsl(120, 75%, 94%); opacity:1.0;                     line-height:1.75"><font color="black"> праздновать                    </font></mark><mark style="background-color: hsl(120, 75%, 94%); opacity:1.0;                     line-height:1.75"><font color="black"> день                    </font></mark><mark style="background-color: hsl(120, 75%, 83%); opacity:1.0;                     line-height:1.75"><font color="black"> победы                    </font></mark><mark style="background-color: hsl(0, 75%, 100%); opacity:1.0;                     line-height:1.75"><font color="black"> [SEP]                    </font></mark></td><tr></table>
#                                                                         True: RT; Pred: RT
# <table width: 100%><div style="border-top: 1px solid; margin-top: 5px;             padding-top: 5px; display: inline-block"><b>Legend: </b><span style="display: inline-block; width: 10px; height: 10px;                 border: 1px solid; background-color:                 hsl(0, 75%, 60%)"></span> Negative  <span style="display: inline-block; width: 10px; height: 10px;                 border: 1px solid; background-color:                 hsl(0, 75%, 100%)"></span> Neutral  <span style="display: inline-block; width: 10px; height: 10px;                 border: 1px solid; background-color:                 hsl(120, 75%, 50%)"></span> Positive  </div><tr><th>True Label</th><th>Predicted Label</th><th>Attribution Label</th><th>Attribution Score</th><th>Word Importance</th><tr><td><text style="padding-right:2em"><b>0</b></text></td><td><text style="padding-right:2em"><b>LABEL_0 (1.00)</b></text></td><td><text style="padding-right:2em"><b>LABEL_0</b></text></td><td><text style="padding-right:2em"><b>2.31</b></text></td><td><mark style="background-color: hsl(0, 75%, 100%); opacity:1.0;                     line-height:1.75"><font color="black"> [CLS]                    </font></mark><mark style="background-color: hsl(120, 75%, 87%); opacity:1.0;                     line-height:1.75"><font color="black"> в                    </font></mark><mark style="background-color: hsl(120, 75%, 75%); opacity:1.0;                     line-height:1.75"><font color="black"> минобороны                    </font></mark><mark style="background-color: hsl(120, 75%, 80%); opacity:1.0;                     line-height:1.75"><font color="black"> прокомментировали                    </font></mark><mark style="background-color: hsl(120, 75%, 72%); opacity:1.0;                     line-height:1.75"><font color="black"> возвращение                    </font></mark><mark style="background-color: hsl(120, 75%, 85%); opacity:1.0;                     line-height:1.75"><font color="black"> специалистов                    </font></mark><mark style="background-color: hsl(120, 75%, 87%); opacity:1.0;                     line-height:1.75"><font color="black"> из                    </font></mark><mark style="background-color: hsl(0, 75%, 97%); opacity:1.0;                     line-height:1.75"><font color="black"> итал                    </font></mark><mark style="background-color: hsl(120, 75%, 97%); opacity:1.0;                     line-height:1.75"><font color="black"> ##ии                    </font></mark><mark style="background-color: hsl(0, 75%, 100%); opacity:1.0;                     line-height:1.75"><font color="black"> [SEP]                    </font></mark></td><tr></table>

# %%
cls_explainer(sent);

# %% [markdown]
# Positive attribution numbers indicate a word contributes positively towards the predicted class, while negative numbers indicate a word contributes negatively towards the predicted class.

# %%
cname_to_agency[cls_explainer.predicted_class_name]
# Out:
# 'Lenta'

# %%
cls_explainer.visualize('bert-discr-vis.html');
# Out:
# <table width: 100%><div style="border-top: 1px solid; margin-top: 5px;             padding-top: 5px; display: inline-block"><b>Legend: </b><span style="display: inline-block; width: 10px; height: 10px;                 border: 1px solid; background-color:                 hsl(0, 75%, 60%)"></span> Negative  <span style="display: inline-block; width: 10px; height: 10px;                 border: 1px solid; background-color:                 hsl(0, 75%, 100%)"></span> Neutral  <span style="display: inline-block; width: 10px; height: 10px;                 border: 1px solid; background-color:                 hsl(120, 75%, 50%)"></span> Positive  </div><tr><th>True Label</th><th>Predicted Label</th><th>Attribution Label</th><th>Attribution Score</th><th>Word Importance</th><tr><td><text style="padding-right:2em"><b>1</b></text></td><td><text style="padding-right:2em"><b>LABEL_1 (0.89)</b></text></td><td><text style="padding-right:2em"><b>LABEL_1</b></text></td><td><text style="padding-right:2em"><b>1.22</b></text></td><td><mark style="background-color: hsl(0, 75%, 100%); opacity:1.0;                     line-height:1.75"><font color="black"> [CLS]                    </font></mark><mark style="background-color: hsl(120, 75%, 100%); opacity:1.0;                     line-height:1.75"><font color="black"> в                    </font></mark><mark style="background-color: hsl(120, 75%, 64%); opacity:1.0;                     line-height:1.75"><font color="black"> столичной                    </font></mark><mark style="background-color: hsl(120, 75%, 83%); opacity:1.0;                     line-height:1.75"><font color="black"> квартире                    </font></mark><mark style="background-color: hsl(0, 75%, 86%); opacity:1.0;                     line-height:1.75"><font color="black"> нашли                    </font></mark><mark style="background-color: hsl(120, 75%, 93%); opacity:1.0;                     line-height:1.75"><font color="black"> тела                    </font></mark><mark style="background-color: hsl(120, 75%, 80%); opacity:1.0;                     line-height:1.75"><font color="black"> пенсионер                    </font></mark><mark style="background-color: hsl(120, 75%, 100%); opacity:1.0;                     line-height:1.75"><font color="black"> ##ки                    </font></mark><mark style="background-color: hsl(0, 75%, 100%); opacity:1.0;                     line-height:1.75"><font color="black"> и                    </font></mark><mark style="background-color: hsl(0, 75%, 96%); opacity:1.0;                     line-height:1.75"><font color="black"> ее                    </font></mark><mark style="background-color: hsl(120, 75%, 99%); opacity:1.0;                     line-height:1.75"><font color="black"> сына                    </font></mark><mark style="background-color: hsl(0, 75%, 99%); opacity:1.0;                     line-height:1.75"><font color="black"> ##-                    </font></mark><mark style="background-color: hsl(120, 75%, 99%); opacity:1.0;                     line-height:1.75"><font color="black"> ##ин                    </font></mark><mark style="background-color: hsl(120, 75%, 97%); opacity:1.0;                     line-height:1.75"><font color="black"> ##вали                    </font></mark><mark style="background-color: hsl(0, 75%, 99%); opacity:1.0;                     line-height:1.75"><font color="black"> ##да                    </font></mark><mark style="background-color: hsl(0, 75%, 100%); opacity:1.0;                     line-height:1.75"><font color="black"> [SEP]                    </font></mark></td><tr></table>
# <table width: 100%><div style="border-top: 1px solid; margin-top: 5px;             padding-top: 5px; display: inline-block"><b>Legend: </b><span style="display: inline-block; width: 10px; height: 10px;                 border: 1px solid; background-color:                 hsl(0, 75%, 60%)"></span> Negative  <span style="display: inline-block; width: 10px; height: 10px;                 border: 1px solid; background-color:                 hsl(0, 75%, 100%)"></span> Neutral  <span style="display: inline-block; width: 10px; height: 10px;                 border: 1px solid; background-color:                 hsl(120, 75%, 50%)"></span> Positive  </div><tr><th>True Label</th><th>Predicted Label</th><th>Attribution Label</th><th>Attribution Score</th><th>Word Importance</th><tr><td><text style="padding-right:2em"><b>1</b></text></td><td><text style="padding-right:2em"><b>LABEL_1 (0.89)</b></text></td><td><text style="padding-right:2em"><b>LABEL_1</b></text></td><td><text style="padding-right:2em"><b>1.22</b></text></td><td><mark style="background-color: hsl(0, 75%, 100%); opacity:1.0;                     line-height:1.75"><font color="black"> [CLS]                    </font></mark><mark style="background-color: hsl(120, 75%, 100%); opacity:1.0;                     line-height:1.75"><font color="black"> в                    </font></mark><mark style="background-color: hsl(120, 75%, 64%); opacity:1.0;                     line-height:1.75"><font color="black"> столичной                    </font></mark><mark style="background-color: hsl(120, 75%, 83%); opacity:1.0;                     line-height:1.75"><font color="black"> квартире                    </font></mark><mark style="background-color: hsl(0, 75%, 86%); opacity:1.0;                     line-height:1.75"><font color="black"> нашли                    </font></mark><mark style="background-color: hsl(120, 75%, 93%); opacity:1.0;                     line-height:1.75"><font color="black"> тела                    </font></mark><mark style="background-color: hsl(120, 75%, 80%); opacity:1.0;                     line-height:1.75"><font color="black"> пенсионер                    </font></mark><mark style="background-color: hsl(120, 75%, 100%); opacity:1.0;                     line-height:1.75"><font color="black"> ##ки                    </font></mark><mark style="background-color: hsl(0, 75%, 100%); opacity:1.0;                     line-height:1.75"><font color="black"> и                    </font></mark><mark style="background-color: hsl(0, 75%, 96%); opacity:1.0;                     line-height:1.75"><font color="black"> ее                    </font></mark><mark style="background-color: hsl(120, 75%, 99%); opacity:1.0;                     line-height:1.75"><font color="black"> сына                    </font></mark><mark style="background-color: hsl(0, 75%, 99%); opacity:1.0;                     line-height:1.75"><font color="black"> ##-                    </font></mark><mark style="background-color: hsl(120, 75%, 99%); opacity:1.0;                     line-height:1.75"><font color="black"> ##ин                    </font></mark><mark style="background-color: hsl(120, 75%, 97%); opacity:1.0;                     line-height:1.75"><font color="black"> ##вали                    </font></mark><mark style="background-color: hsl(0, 75%, 99%); opacity:1.0;                     line-height:1.75"><font color="black"> ##да                    </font></mark><mark style="background-color: hsl(0, 75%, 100%); opacity:1.0;                     line-height:1.75"><font color="black"> [SEP]                    </font></mark></td><tr></table>

# %% [markdown]
# ### Layers attention

# %%
inputs = tokenizer.encode_plus(sent, return_tensors='pt', add_special_tokens=True)
input_ids = inputs['input_ids'].cuda()
token_type_ids = inputs['token_type_ids'].cuda()

# %%
out = model(input_ids, token_type_ids=token_type_ids)

# %%
attention = out[-1]

# %%
# sentence_b_start = token_type_ids[0].tolist().index(1)
input_id_list = input_ids[0].tolist() # Batch index 0
tokens = tokenizer.convert_ids_to_tokens(input_id_list)

# %%
model_view(attention, tokens)
# Out:
# <script src="https://cdnjs.cloudflare.com/ajax/libs/require.js/2.3.6/require.min.js"></script>
#             <div id='bertviz-3cb0a74f5f08435984ee01b95e73168d'>
#                 <div id='vis'></div>
#             </div>

# %%
head_view(attention, tokens)
# Out:
# <script src="https://cdnjs.cloudflare.com/ajax/libs/require.js/2.3.6/require.min.js"></script>
#             <div id='bertviz-4fb67e8bca194a5cb1b6df1f7fcc7ac3'>
#               <span style="user-select:none">
#                 Layer: <select id="layer"></select>
#               </span>
#               <div id='vis'></div>
#             </div>
